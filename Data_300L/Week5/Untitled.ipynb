# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/Users/connorjohnson/Desktop/Data_300L/Week5/netflix_titles.csv')

plt.hist(df['release_year'])

plt.show()

# %%
import numpy as np 
data = df['release_year']
plt.hist(data, bins=np.arange(min(data), max(data)+ 1, 1))
plt.show()

# %%
plt.hist(data, bins = 20)
plt.show()

# %%
file - pd.read_csv("/Users/connorjohnson/Desktop/Data_300L/Week5/seattle_weather_1948-2017.csv")
plt.plot(file['Date'].tall(50), file)
